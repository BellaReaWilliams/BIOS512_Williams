# %% [markdown]
# BIOS 512

# %% [markdown]
# Homework 4

# %% [markdown]
# Bella Williams

# %% [markdown]
# Question 1

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.2     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
table_a <- tibble(
  SKU = c(102345, 104567, 108912, 109876, 112233),
  Fruit = c("Apple", "Orange", "Mango", "Blueberry", "Watermelon"),
  Color = c("Red", "Orange", "Yellow", "Blue", "Green"),
  Price = c(1.20, 1.40, 1.70, 3.50, 4.40),
  In_Stock = c("Yes", "Yes", "No", "Yes", "No")
)

# %%
table_b <- tibble(
  SKU = c(102345, 105432, 106789, 104567, 107654),
  Fruit = c("Apple", "Banana", "Grape", "Orange", "Pear"),
  Color = c("Red", "Yellow", "Purple", "Orange", "Green"),
  Sale_Price = c(1.00, 0.50, 2.00, 1.20, 1.10),
  Number_in_Stock = c(50, 120, 0, 75, 0)
)

# %% [markdown]
# A) Left join

# %%
left_join(table_a, table_b, by = "SKU")
# Out:
#   SKU    Fruit.x    Color.x Price In_Stock Fruit.y Color.y Sale_Price
# 1 102345 Apple      Red     1.2   Yes      Apple   Red     1.0
# 2 104567 Orange     Orange  1.4   Yes      Orange  Orange  1.2
# 3 108912 Mango      Yellow  1.7   No       NA      NA       NA
# 4 109876 Blueberry  Blue    3.5   Yes      NA      NA       NA
# 5 112233 Watermelon Green   4.4   No       NA      NA       NA
#   Number_in_Stock
# 1 50
# 2 75
# 3 NA
# 4 NA
# 5 NA

# %% [markdown]
# b) Right join

# %%
right_join(table_a, table_b, by = "SKU")
# Out:
#   SKU    Fruit.x Color.x Price In_Stock Fruit.y Color.y Sale_Price
# 1 102345 Apple   Red     1.2   Yes      Apple   Red     1.0
# 2 104567 Orange  Orange  1.4   Yes      Orange  Orange  1.2
# 3 105432 NA      NA       NA   NA       Banana  Yellow  0.5
# 4 106789 NA      NA       NA   NA       Grape   Purple  2.0
# 5 107654 NA      NA       NA   NA       Pear    Green   1.1
#   Number_in_Stock
# 1  50
# 2  75
# 3 120
# 4   0
# 5   0

# %% [markdown]
# c) Inner join

# %%
inner_join(table_a, table_b, by = "SKU")
# Out:
#   SKU    Fruit.x Color.x Price In_Stock Fruit.y Color.y Sale_Price
# 1 102345 Apple   Red     1.2   Yes      Apple   Red     1.0
# 2 104567 Orange  Orange  1.4   Yes      Orange  Orange  1.2
#   Number_in_Stock
# 1 50
# 2 75

# %% [markdown]
# d) Full join

# %%
full_join(table_a, table_b, by = "SKU")
# Out:
#   SKU    Fruit.x    Color.x Price In_Stock Fruit.y Color.y Sale_Price
# 1 102345 Apple      Red     1.2   Yes      Apple   Red     1.0
# 2 104567 Orange     Orange  1.4   Yes      Orange  Orange  1.2
# 3 108912 Mango      Yellow  1.7   No       NA      NA       NA
# 4 109876 Blueberry  Blue    3.5   Yes      NA      NA       NA
# 5 112233 Watermelon Green   4.4   No       NA      NA       NA
# 6 105432 NA         NA       NA   NA       Banana  Yellow  0.5
# 7 106789 NA         NA       NA   NA       Grape   Purple  2.0
# 8 107654 NA         NA       NA   NA       Pear    Green   1.1
#   Number_in_Stock
# 1  50
# 2  75
# 3  NA
# 4  NA
# 5  NA
# 6 120
# 7   0
# 8   0

# %% [markdown]
# e) Semi join

# %%
semi_join(table_a, table_b, by = "SKU")
# Out:
#   SKU    Fruit  Color  Price In_Stock
# 1 102345 Apple  Red    1.2   Yes
# 2 104567 Orange Orange 1.4   Yes

# %% [markdown]
# f) Anti join

# %%
anti_join(table_a, table_b, by = "SKU")
# Out:
#   SKU    Fruit      Color  Price In_Stock
# 1 108912 Mango      Yellow 1.7   No
# 2 109876 Blueberry  Blue   3.5   Yes
# 3 112233 Watermelon Green  4.4   No

# %% [markdown]
# Question 2

# %%
A)

# %%
demographics <- read_csv("demographics.csv")
full <- read_csv("full.csv")
hospitals <- read_csv("hospitals.csv")
patient_names <- read_csv("patient_names.csv")
treatment_info <- read_csv("treatment_info.csv")
# Out:
# Rows: 35 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): patient_id, gender, race, ethnicity
# dbl (1): age
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 35 Columns: 16
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (12): patient_id, name, gender, race, ethnicity, condition, treatment, ...
# dbl   (2): age, patient_zipcode
# date  (2): admission_date, release_date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 5 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): hospital_id, hospital_name, hospital_address, hospital_city, hospit...
# ...

# %% [markdown]
# B)

# %%
glimpse(demographics)
glimpse(full)
glimpse(hospitals)
glimpse(patient_names)
glimpse(treatment_info)
# Out:
# Rows: 35
# Columns: 5
# $ patient_id <chr> "P001", "P002", "P003", "P004", "P005", "P006", "P007", "P0…
# $ age        <dbl> 51, 73, 49, 6, 64, 38, 36, 22, 20, 85, 61, 23, 54, 22, 29, …
# $ gender     <chr> "Male", "Male", NA, "Other", "Other", "Other", "Female", "O…
# $ race       <chr> "Hispanic", "Hispanic", "White", "White", "White", "Hispani…
# $ ethnicity  <chr> "Non-Hispanic", "Non-Hispanic", "Non-Hispanic", "Non-Hispan…
# Rows: 35
# Columns: 16
# $ patient_id      <chr> "P001", "P002", "P003", "P004", "P005", "P006", "P007"…
# $ name            <chr> "Mary Hicks", "Matthew Christensen", "Lisa Graham", "G…
# $ age             <dbl> 51, 73, 49, 6, 64, 38, 36, 22, 20, 85, 61, 23, 54, 22,…
# $ gender          <chr> "Male", "Male", NA, "Other", "Other", "Other", "Female…
# $ race            <chr> "Hispanic", "Hispanic", "White", "White", "White", "Hi…
# $ ethnicity       <chr> "Non-Hispanic", "Non-Hispanic", "Non-Hispanic", "Non-H…
# ...

# %% [markdown]
# Question 3

# %%
full_long <- full %>%
  pivot_longer(
    cols = -c(patient_id, name), 
    names_to = "variable", 
    values_to = "value", 
    values_transform = list(value = as.character)
  )

obs_per_patient <- full_long %>%
  group_by(patient_id, name) %>% 
  tally(name = "n_observations") %>% 
  arrange(desc(n_observations))

obs_per_patient
# Out:
#    patient_id name                n_observations
# 1  P001       Mary Hicks          14
# 2  P002       Matthew Christensen 14
# 3  P003       Lisa Graham         14
# 4  P004       Greg Brown          14
# 5  P005       Joshua Baker        14
# 6  P006       Wendy Richardson    14
# 7  P007       April Sanchez       14
# 8  P008       Melinda Moody       14
# 9  P009       Dylan Lopez DVM     14
# 10 P010       Maria Bruce         14
# 11 P011       Kristine Lewis      14
# 12 P012       Jessica Ibarra      14
# 13 P013       Matthew Rogers      14
# 14 P014       Joseph Thompson     14
# 15 P015       Holly Contreras     14
# 16 P016       Heather Chandler    14
# 17 P017       John Brown          14
# 18 P018       Nathan Chase        14
# 19 P019       Casey Norman        14
# 20 P020       Nicholas Smith MD   14
# 21 P021       Mary Cobb           14
# 22 P022       Thomas Logan        14
# 23 P023       Anthony Anderson    14
# 24 P024       Matthew Jones       14
# ...

# %% [markdown]
# Question 4

# %%
full_chr <- full %>%
  select(patient_id, name, where(is.character)) %>%
  pivot_longer(
    cols = -c(patient_id, name),
    names_to = "variable_chr",
    values_to = "value_chr"
  ) %>%
  group_by(patient_id, name) %>%
  mutate(row = row_number()) %>%
  ungroup()

full_num <- full %>%
  select(patient_id, name, where(is.numeric)) %>%
  pivot_longer(
    cols = -c(patient_id, name),
    names_to = "variable_num",
    values_to = "value_num"
  ) %>%
  group_by(patient_id, name) %>%
  mutate(row = row_number()) %>%
  ungroup()

full_date <- full %>%
  select(patient_id, name, where(lubridate::is.Date)) %>%
  pivot_longer(
    cols = -c(patient_id, name),
    names_to = "variable_date",
    values_to = "value_date"
  ) %>%
  group_by(patient_id, name) %>%
  mutate(row = row_number()) %>%
  ungroup()

full_long_types <- full_chr %>%
  full_join(full_num, by = c("patient_id", "name", "row")) %>%
  full_join(full_date, by = c("patient_id", "name", "row"))

obs_type_per_patient <- full_long_types %>%
  group_by(patient_id, name) %>%
  summarise(
    n_chr  = sum(!is.na(value_chr)),
    n_num  = sum(!is.na(value_num)),
    n_date = sum(!is.na(value_date)),
    .groups = "drop"
  ) %>%
  arrange(desc(n_chr))

obs_type_per_patient
# Out:
#    patient_id name                n_chr n_num n_date
# 1  P002       Matthew Christensen 10    2     2
# 2  P004       Greg Brown          10    2     2
# 3  P005       Joshua Baker        10    2     2
# 4  P006       Wendy Richardson    10    2     2
# 5  P007       April Sanchez       10    2     2
# 6  P008       Melinda Moody       10    2     2
# 7  P009       Dylan Lopez DVM     10    2     2
# 8  P010       Maria Bruce         10    2     2
# 9  P011       Kristine Lewis      10    2     2
# 10 P012       Jessica Ibarra      10    2     2
# 11 P013       Matthew Rogers      10    2     2
# 12 P014       Joseph Thompson     10    2     2
# 13 P015       Holly Contreras     10    2     2
# 14 P017       John Brown          10    2     2
# 15 P018       Nathan Chase        10    2     2
# 16 P020       Nicholas Smith MD   10    2     2
# 17 P021       Mary Cobb           10    2     2
# 18 P022       Thomas Logan        10    2     2
# ...

# %% [markdown]
# Question 5

# %%
patients_with_hospital <- patient_names %>%
  left_join(hospitals %>% select(hospital_id, hospital_name), 
            by = "hospital_id") %>%
  select(patient_id, name, hospital_name)

patients_with_hospital
# Out:
#    patient_id name                hospital_name
# 1  P001       Mary Hicks          Greenwood Medical Center
# 2  P002       Matthew Christensen Mountainview Clinic
# 3  P003       Lisa Graham         Mountainview Clinic
# 4  P004       Greg Brown          Sunrise Health
# 5  P005       Joshua Baker        Greenwood Medical Center
# 6  P006       Wendy Richardson    Sunrise Health
# 7  P007       April Sanchez       Mountainview Clinic
# 8  P008       Melinda Moody       Sunrise Health
# 9  P009       Dylan Lopez DVM     Greenwood Medical Center
# 10 P010       Maria Bruce         Mountainview Clinic
# 11 P011       Kristine Lewis      Valley General Hospital
# 12 P012       Jessica Ibarra      Lakeside Hospital
# 13 P013       Matthew Rogers      Valley General Hospital
# 14 P014       Joseph Thompson     Sunrise Health
# 15 P015       Holly Contreras     Greenwood Medical Center
# 16 P016       Heather Chandler    Greenwood Medical Center
# ...

# %% [markdown]
# Question 6

# %%
 patient_full_info <- patient_names %>%
     left_join(demographics %>% select(patient_id, age, gender), by = "patient_id") %>%
     left_join(treatment_info %>% select(condition_id, condition, treatment), by = "condition_id") %>%
     select(patient_id, name, age, gender, condition, treatment)
 
 patient_full_info
# Out:
#    patient_id name                age gender condition
# 1  P001       Mary Hicks          51  Male   Cancer
# 2  P002       Matthew Christensen 73  Male   Heart Disease
# 3  P003       Lisa Graham         49  NA     Asthma
# 4  P004       Greg Brown           6  Other  Heart Disease
# 5  P005       Joshua Baker        64  Other  Heart Disease
# 6  P006       Wendy Richardson    38  Other  Asthma
# 7  P007       April Sanchez       36  Female Asthma
# 8  P008       Melinda Moody       22  Other  Stroke
# 9  P009       Dylan Lopez DVM     20  Male   Asthma
# 10 P010       Maria Bruce         85  Other  Fracture
# 11 P011       Kristine Lewis      61  Female Asthma
# 12 P012       Jessica Ibarra      23  Other  Fracture
# 13 P013       Matthew Rogers      54  Female Fracture
# 14 P014       Joseph Thompson     22  Other  Fracture
# 15 P015       Holly Contreras     29  Male   Heart Disease
# 16 P016       Heather Chandler    74  Female Asthma
# ...

# %% [markdown]
# Question 7

# %%
install.packages("skimr")

library(skimr)
library(dplyr)
library(purrr)
library(readr)

df <- read_csv(
  "https://raw.githubusercontent.com/Vincent-Toups/bios512/refs/heads/main/nuforc_workshop/nuforc_sightings.csv",
  show_col_types = FALSE
)

 low_unique_cols <- c("shape", "has_image", "explanation")
 unique_values_list <- map(low_unique_cols, function(col_name) {
     df %>%
         pull(!!sym(col_name)) %>%
         unique() %>%
         sort()
 })
names(unique_values_list) <- low_unique_cols
unique_values_list
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)
# $shape
#  [1] "changing"  "Changing"  "Chevron"   "cigar"     "Cigar"     "circle"
#  [7] "Circle"    "Cone"      "Cross"     "Cube"      "cylinder"  "Cylinder"
# [13] "diamond"   "Diamond"   "Disk"      "egg"       "Egg"       "fireball"
# [19] "Fireball"  "flash"     "Flash"     "Formation" "light"     "Light"
# [25] "Orb"       "other"     "Other"     "oval"      "Oval"      "rectangle"
# [31] "Rectangle" "sphere"    "Sphere"    "Star"      "Teardrop"  "triangle"
# [37] "Triangle"  "unknown"   "Unknown"
#
# $has_image
# [1] "Y"
#
# $explanation
#  [1] "Aircraft"              "Aircraft?"             "Animal?"
#  [4] "Aurora Borealis?"      "Aurora?"               "Ball Lightning?"
#  [7] "Balloon"               "Balloon?"              "Balloons"
# [10] "Balloons?"             "Bat?"                  "Bird"
# [13] "Bird?"                 "Birds"                 "birds?"
# ...

# %% [markdown]
# Question 8

# %%
 state_map <- tibble(
     state_full = state.name,   
     state_abbr = state.abb     
 )
 
 us_state_counts <- df %>%
     filter(country == "USA") %>%                
     distinct(id, .keep_all = TRUE) %>%          
     mutate(state_clean = case_when(
         state %in% state.abb ~ state,                                      
         state %in% state.name ~ state_map$state_abbr[match(state, state_map$state_full)], 
         TRUE ~ NA_character_                                              
     )) %>%
     filter(!is.na(state_clean)) %>%                                        
     group_by(state_clean) %>%
     tally(name = "num_sightings") %>%
     filter(num_sightings > 1) %>%                                         
     arrange(desc(num_sightings))
 
 
 ggplot(us_state_counts, aes(x = reorder(state_clean, -num_sightings), y = num_sightings)) +
     geom_bar(stat = "identity", fill = "steelblue") +
     labs(title = "Number of UFO Sightings by US State",
          x = "State",
          y = "Number of Sightings") +
     theme_minimal() +
     theme(axis.text.x = element_text(angle = 90, hjust = 1, vjust = 0.5))

![Caption for the picture.](https://hub.gesis.mybinder.org/user/bellareawilliam-nment1_williams-mlo6hixv/rstudio/files/ufo_sightings.png)
# Out:
# Error in parse(text = x, srcfile = src): <text>:29:2: unexpected '['
# 28:
# 29: ![
#      ^
# Traceback:
